# %%
import pickle
import pandas as pd

# Read DF from pickle.
with open('results_with_duplicates.df', 'rb') as f:
    lst = pickle.load(f)

df = pd.DataFrame(lst)

df.head()
# Out:
#                                               source  \
# 0  10-12-2011__Amazon Kindle Support_ _cust.servi...
# 1  10-3-2009_interiery@mercurystar.cz_Vase objedn...
# 2  10-3-2009_interiery@mercurystar.cz_Vase regist...
# 3  11-3-2009_interiery@mercurystar.cz_OBJEDNAVKA ...
# 4  12-3-2009_interiery@mercurystar.cz_OBJEDNAVKA ...
#
#                    from_str                 from_email  \
# 0     Amazon Kindle Support  cust.service03@amazon.com
# 1  interiery@mercurystar.cz   interiery@mercurystar.cz
# 2  interiery@mercurystar.cz   interiery@mercurystar.cz
# 3  interiery@mercurystar.cz   interiery@mercurystar.cz
# 4  interiery@mercurystar.cz   interiery@mercurystar.cz
#
#                         to_str                     to_email cc bcc  \
# 0  dalibor.hlava.alt@gmail.com  dalibor.hlava.alt@gmail.com
# 1      dalibor.hlava@gmail.com      dalibor.hlava@gmail.com
# 2      dalibor.hlava@gmail.com      dalibor.hlava@gmail.com
# ...
