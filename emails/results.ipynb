# %%
import json
import sys 

import pandas as pd

import os

secrets_file_name = 'project.secrets'
with open(secrets_file_name, "r") as secrets_file:
    secrets_data = json.load(secrets_file)

data_dir = secrets_data['data-dir']

df = pd.read_csv(os.path.join(data_dir, 'results.csv'))
df.head()
# Out:
#                                               source                   from  \
# 0  1-2-2018__Jaroslav Chýle - MBSR_ _mbsr@email.c...  Jaroslav Chýle - MBSR
# 1  1-2-2018__Jiří Rak_ _jiri.rak@mensa.cz__[Mensa...               Jiří Rak
# 2  1-2-2018__Marc (Airbnb)_ _express@airbnb.com__...          Marc (Airbnb)
# 3  1-2-2018__Mgr. Iva Hlavová_ _ivahlavova@seznam...       Mgr. Iva Hlavová
# 4  1-2-2018__Miroslava Cehelska_ _forwarder@gmcsl...     Miroslava Cehelska
#
#                     from_email                       to  \
# 0             _mbsr@email.cz__                      NaN
# 1         _jiri.rak@mensa.cz__            Dalibor Hlava
# 2     _express@airbnb.com__RE_  dalibor.hlava@gmail.com
# 3   _ivahlavova@seznam.cz__Re_            Dalibor Hlava
# 4  _forwarder@gmcslovakia.sk__            Dalibor Hlava
#
#                     to_str                                            subject  \
# 0                      NaN                        Kurz MBSR od 10. ledna 2018
# 1            Dalibor Hlava  [Mensa] Jarní setkání Mens ČR v Zaječí - otevř...
# 2  dalibor.hlava@gmail.com  RE: Rezervace Central cozy apartment 3B/ROOM B...
# 3            Dalibor Hlava                            Re: Re: Dálniční známka
# 4            Dalibor Hlava                                         update GMC
#
#                 datetime_utc  attachments  attachments-count  \
# 0  2018-02-01T13:42:10+00:00          NaN                  1
# 1  2018-02-01T19:06:29+00:00          NaN                  1
# 2  2018-02-01T14:38:50+00:00          NaN                  1
# 3  2018-02-01T20:01:42+00:00          NaN                  1
# 4  2018-02-01T09:26:03+00:00          NaN                  1
#
#                        content-hash  content-length   encoding
# 0  93bc51c7fcb621f4fec7c9740ccf69aa             396  UTF-8-SIG
# 1  19701b6b4520460917c39b1440cd02a0            1744  UTF-8-SIG
# 2  a0bbee9368af2e3a8b9c223e4bcebbe3            5614  UTF-8-SIG
# 3  0f79a05ea81406703af1b97450e6b26e             588  UTF-8-SIG
# 4  8338190913e53f36ca632affef4864a4             717  UTF-8-SIG
